# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruv5narang/Harvard-Banking-Project/blob/master/helloworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Hello to world
import pandas
first_name = 'Dhruv'
last_name = 'Narang'

# %%
print (first_name)
# Out:
# Dhruv

# %%
print(last_name)
# Out:
# Narang
